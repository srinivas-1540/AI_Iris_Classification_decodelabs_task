# %%
# Numerical operations
import numpy as np

# Data manipulation
import pandas as pd

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Load Iris dataset
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
print(type(iris))
# Out:
# <class 'sklearn.utils._bunch.Bunch'>

# %%
print(iris.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
df["species"].value_counts() # type: ignore
# Out:
# species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
sns.pairplot(df, hue="species")
plt.show()

# %%
# Features (Input)
X = df.iloc[:, :-1]

# Target (Output)
y = df["species"]

# %%
print(X.head())
print(y.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: species, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
print(X_scaled[:5])
# Out:
# [[-0.90068117  1.01900435 -1.34022653 -1.3154443 ]
#  [-1.14301691 -0.13197948 -1.34022653 -1.3154443 ]
#  [-1.38535265  0.32841405 -1.39706395 -1.3154443 ]
#  [-1.50652052  0.09821729 -1.2833891  -1.3154443 ]
#  [-1.02184904  1.24920112 -1.34022653 -1.3154443 ]]

# %%
# Separate features and target
X = df.iloc[:, :-1]
y = df["species"]

print(X.head())
print(y.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: species, dtype: int64

# %%
import joblib

# Save model
joblib.dump(knn, "saved_model/iris_knn_model.pkl")

# Save scaler
joblib.dump(scaler, "saved_model/scaler.pkl")

print("Model and scaler saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 4
#       1 import joblib
#       2
#       3 # Save model
# ----> 4 joblib.dump(knn, "saved_model/iris_knn_model.pkl")
#       5
#       6 # Save scaler
#       7 joblib.dump(scaler, "saved_model/scaler.pkl")
#
# File c:\Users\SRINIVAS\OneDrive\Desktop\AI_Iris_Classification\venv\Lib\site-packages\joblib\numpy_pickle.py:599, in dump(value, filename, compress, protocol)
#     597         NumpyPickler(f, protocol=protocol).dump(value)
#     598 elif is_filename:
# --> 599     with open(filename, "wb") as f:
#     600         NumpyPickler(f, protocol=protocol).dump(value)
#     601 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'saved_model/iris_knn_model.pkl'

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\SRINIVAS\OneDrive\Desktop\AI_Iris_Classification

# %%
import os

print(os.listdir())
# Out:
# ['.vscode', 'app.py', 'confusion matrix.png', 'dataset', 'images', 'model.py', 'notebook.ipynb', 'pairplot.png', 'README.md', 'requirements.txt', 'saved_model', 'venv']

# %%
import os

print(os.path.isdir("saved_model"))
print(os.path.isfile("saved_model"))
# Out:
# False
# True

# %%
import os

os.remove("saved_model")
os.makedirs("saved_model")

# %%
import os
import joblib

save_path = os.path.join(os.getcwd(), "saved_model", "iris_knn_model.pkl")

joblib.dump(knn, save_path)

scaler_path = os.path.join(os.getcwd(), "saved_model", "scaler.pkl")

joblib.dump(scaler, scaler_path)

print("✅ Model saved successfully!")
print(save_path)
# Out:
# ✅ Model saved successfully!
# c:\Users\SRINIVAS\OneDrive\Desktop\AI_Iris_Classification\saved_model\iris_knn_model.pkl

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

print(X_scaled[:5])
# Out:
# [[-0.90068117  1.01900435 -1.34022653 -1.3154443 ]
#  [-1.14301691 -0.13197948 -1.34022653 -1.3154443 ]
#  [-1.38535265  0.32841405 -1.39706395 -1.3154443 ]
#  [-1.50652052  0.09821729 -1.2833891  -1.3154443 ]
#  [-1.02184904  1.24920112 -1.34022653 -1.3154443 ]]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

print("Training Features :", X_train.shape)
print("Testing Features  :", X_test.shape)

print("Training Labels   :", y_train.shape)
print("Testing Labels    :", y_test.shape)
# Out:
# Training Features : (120, 4)
# Testing Features  : (30, 4)
# Training Labels   : (120,)
# Testing Labels    : (30,)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(
    n_neighbors=5
)

# %%
knn.fit(
    X_train,
    y_train
)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)

print("Predicted Labels")

print(y_pred)

print()

print("Actual Labels")

print(y_test.values)
# Out:
# Predicted Labels
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]
#
# Actual Labels
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(
    y_test,
    y_pred
)

print("Accuracy :", accuracy)
# Out:
# Accuracy : 1.0

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(
    y_test,
    y_pred
)

print(cm)
# Out:
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]

# %%
plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    cmap="Greens",
    fmt="d"
)

plt.xlabel("Predicted")

plt.ylabel("Actual")

plt.title("Confusion Matrix")

plt.show()

# %%
from sklearn.metrics import classification_report

print(
    classification_report(
        y_test,
        y_pred
    )
)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
new_flower = [[5.1, 3.5, 1.4, 0.2]]

new_scaled = scaler.transform(new_flower)

prediction = knn.predict(new_scaled)

flower_name = iris.target_names[prediction][0]

print("Predicted Flower :", flower_name)
# Out:
# Predicted Flower : setosa
# c:\Users\SRINIVAS\OneDrive\Desktop\AI_Iris_Classification\venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
X = df.iloc[:, :-1]

scaler.fit(X)
# Out:
# StandardScaler()

# %%
new_flower = [[5.1, 3.5, 1.4, 0.2]]

# %%
df["species"].value_counts()
# Out:
# species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
if 'df' not in globals():
    df = pd.DataFrame(iris.data, columns=iris.feature_names)
    df["species"] = iris.target

sns.pairplot(df, hue="species")
plt.show()
plt.show()

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='str')

# %%
df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

df["species"] = iris.target

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
